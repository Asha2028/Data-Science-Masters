# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [raw]
# Flask is a web application framework written in python.
#
# Advantages:
#
# 1. Unlike Django framework, Flask is very Pythonic.
# 2. It is east to get started with Flask, because it doesn't have huge learning curve.
# 3. It is very explicit, which increases the readability.
# 4. It is a lightweight framework that offers hassle-free development.
# 5. Provides flexibility to the developer to experiment with their modules or architecture.
# 6. It is suitable for small projects.
# 7. Offers a built-in development server and fast debugger.
# 8. Easily scalable for the applications
# 9. Support secure cookies.
# 10. Uses Ninja2 Template engine.
# 11. It has integrated support for unit testing.
# 12. APIs are coherent and neat.
# 13. Provide strong WSGI support.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask


app = Flask(__name__)

@app.route("/hello")
def helloWorld():
    return "Hello World!!"

if __name__ == "__main__":
    app.run(host = "0.0.0.0")

# %% [markdown]
# Output:
#
# ![259C81E2-CF7E-45E7-B0F6-706CB5AFEF3D_4_5005_c.jpeg](attachment:259C81E2-CF7E-45E7-B0F6-706CB5AFEF3D_4_5005_c.jpeg)

# %% [raw]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [raw]
# Ans:
#
#     App Routing means mapping the URL to a specific function that will handle the logic for that URL.
#
#     It is used to help users to remember the URLs and make navigation simpler.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__) 

@app.route("/welcome")
def company_welcome():
    return "Welcome to ABC Corporation"

@app.route("/")
def company_details():
    return "Company Name: ABC Corporation Location: INDIA Contact Detail: 999-999-9999"

if __name__ =="__main__":
    app.run(host = "0.0.0.0")

# %% [markdown]
# Output:
#
# ![Screenshot%202023-04-28%20at%2011.23.04%20AM.png](attachment:Screenshot%202023-04-28%20at%2011.23.04%20AM.png)

# %% [markdown]
# ![Screenshot%202023-04-28%20at%2011.32.29%20AM.png](attachment:Screenshot%202023-04-28%20at%2011.32.29%20AM.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [raw]
# Ans:
#
#     The Flask URL Helper function ,url_for() function is used in Flask for URL building.

# %% [markdown]
# ![Screenshot%202023-04-28%20at%207.25.40%20PM.png](attachment:Screenshot%202023-04-28%20at%207.25.40%20PM.png)

# %% [markdown]
# ![Screenshot%202023-04-28%20at%207.25.18%20PM.png](attachment:Screenshot%202023-04-28%20at%207.25.18%20PM.png)

# %% [markdown]
# ![Screenshot%202023-04-28%20at%207.24.58%20PM.png](attachment:Screenshot%202023-04-28%20at%207.24.58%20PM.png)

# %% [markdown]
# ![Screenshot%202023-04-28%20at%207.26.05%20PM.png](attachment:Screenshot%202023-04-28%20at%207.26.05%20PM.png)
